# %%
import numpy as np
import pandas as pd

# %%
FootballPlayers_df = pd.read_csv('/content/football_players.csv')
display(FootballPlayers_df)

# %%
FootballPlayers_df['Career_start']= None
FootballPlayers_df['Nationality']= None
display(FootballPlayers_df)

# %%
FootballPlayers_df.iloc[0,3]= 1992
FootballPlayers_df.iloc[1,3]= 1990
FootballPlayers_df.iloc[2,3]= 2021
FootballPlayers_df.iloc[3,3]= 2015
FootballPlayers_df.iloc[0,4]= "Argentina"
FootballPlayers_df.iloc[1,4]= "Portugal"
FootballPlayers_df.iloc[2,4]= "Spain"
FootballPlayers_df.iloc[3,4]= "Spain"
display(FootballPlayers_df)

# %%
Output_file = '/content/Updated_football_players.csv'
FootballPlayers_df.to_csv(Output_file, index=False)
